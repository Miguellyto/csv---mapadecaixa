# %%
# pip install voila # Transforma App ipynb em AppWeb (voila app.ipynb)
# from cgitb import text
# from distutils.command.upload import upload 
import pandas as pd
import numpy as np
import os
# import sys
import tkinter as tk
from pathlib import Path
from  tkinter import*
import tkinter.messagebox
from tkinter import filedialog
# from PIL import ImageTk, Image
# import lxml 
import ipywidgets as widgets
# from ipywidgets import widgets

# %%
# mapadecaixa = pd.read_csv(os.getcwd() + "\\Movimentação geral (2).csv", encoding='ANSI', sep=',', header=0, thousands = '.', decimal = ',', dtype = {'Valor':np.float64})
# mapadecaixa = pd.read_csv(os.getcwd() + "\\Movimentação geral com 3ag.csv", encoding='ANSI', sep=',', header=0, thousands = '.', decimal = ',', dtype = {'Valor':np.float64})
mapadecaixa = pd.read_csv(os.getcwd() + "\\Movimentação geral LJ 880 CSV.csv", encoding='ANSI', sep=',', header=0, thousands = '.', decimal = ',', dtype = {'Valor':np.float64})
# 'skiprows=20' pula as 20 primeiras linhas. 'skiprows=[ 0, 2, 4, 10 ]', pula as linhas de índice 0, 2, 4 e 10.
# pd.set_option('display.max_columns', None)
# mapadecaixa.head(38) # O número indica a quantidade de linha que a ser exibida.
mapadecaixa.head()
# mapadecaixa
# Out:
#      3o. Agrupamento            4o. Agrupamento                     Descrição  \
# 0  Cartão de Crédito                        NaN  630276895-2/2, 630276895-1/2
# 1  Cartão de Crédito                        NaN  635209191-2/2, 635209191-1/2
# 2   Cartão de Débito                        NaN                 633042330-1/1
# 3   Cartão de Débito                        NaN                 635209553-1/1
# 4           Dinheiro  Carteira Cobrança Simples                 627764966-1/1
#
#   Cliente     Emissão   Valor
# 0     NaN  10/03/2022   53.46
# 1     NaN  16/03/2022  194.94
# 2     NaN  13/03/2022  101.00
# 3     NaN  16/03/2022  500.00
# 4     NaN  01/03/2022  604.00

# %%
widgets.FileUpload(
    accept='',  # Accepted file extension e.g. '.txt', '.pdf', 'image/*', 'image/*,.pdf'
    multiple=False  # True to accept multiple files upload else False
)

# %%
button = widgets.Button(  
    description='Converter CSV',  
)  
button

# %%
    title_textbox = widgets.Text(  
        value = '',  
        description = 'Title:',  
    )  
    title_textbox

# %%
# 3 agrupamento
# quando 3 agrupamento for Cartão de Crédito e 4 agrupamento=vazio faça = Cart Hipercard Pagseguro;10221
# quando 3 agrupamento for Cartão de Débito e 4 agrupamento=vazio faça = Cart Maestro Pagseguro;10221
for index, row in mapadecaixa.iterrows():
    if row['3o. Agrupamento'] == 'Cartão de Crédito':
        mapadecaixa.loc[index, '4o. Agrupamento'] = 'Cart Hipercard Pagseguro;10221'
    elif row['3o. Agrupamento'] == 'Cartão de Débito':
        mapadecaixa.loc[index, '4o. Agrupamento'] = 'Cart Maestro Pagseguro;10221'

mapadecaixa
# Out:
#         3o. Agrupamento                 4o. Agrupamento  \
# 0     Cartão de Crédito  Cart Hipercard Pagseguro;10221
# 1     Cartão de Crédito  Cart Hipercard Pagseguro;10221
# 2      Cartão de Débito    Cart Maestro Pagseguro;10221
# 3      Cartão de Débito    Cart Maestro Pagseguro;10221
# 4              Dinheiro       Carteira Cobrança Simples
# ...                 ...                             ...
# 1907           Dinheiro       Carteira Cobrança Simples
# 1908           Dinheiro       Carteira Cobrança Simples
# 1909           Dinheiro       Carteira Cobrança Simples
# 1910           Dinheiro       Carteira Cobrança Simples
# 1911           Dinheiro       Carteira Cobrança Simples
#
#                          Descrição           Cliente     Emissão   Valor
# 0     630276895-2/2, 630276895-1/2               NaN  10/03/2022   53.46
# 1     635209191-2/2, 635209191-1/2               NaN  16/03/2022  194.94
# 2                    633042330-1/1               NaN  13/03/2022  101.00
# 3                    635209553-1/1               NaN  16/03/2022  500.00
# 4                    627764966-1/1               NaN  01/03/2022  604.00
# ...                            ...               ...         ...     ...
# 1907             RC 1062 / RC 1062  Consumidor Final  24/03/2022   10.00
# 1908             RC 1064 / RC 1064  Consumidor Final  26/03/2022   15.00
# 1909             RC 1066 / RC 1066  Consumidor Final  26/03/2022   10.00
# 1910             RC 1213 / RC 1213  Consumidor Final  30/03/2022   30.00
# 1911             RC 1215 / RC 1215  Consumidor Final  31/03/2022   20.00
#
# [1912 rows x 6 columns]

# %%
#---- Exibe apenas valores que começa com 'RC'
mapadecaixa[mapadecaixa['3o. Agrupamento'].str.startswith('Cheque à vista')]

# %%
#---- MOSTRA A QUANTIDADE DE LINHAS E COLUNAS
mapadecaixa.shape

# %%
# Dividindo a coluna '4o. Agrupamento' em '4o. Agrupamento' e 'DEBITO' onde se encontra o ponto e virgula ';'
# O (.str.replace) pra retirar os - e
mapadecaixa[['4o. Agrupamento','DEBITO']] = mapadecaixa['4o. Agrupamento'].str.split(';', expand=True)
# mapadecaixa.head(38)
# mapadecaixa.head()
mapadecaixa
# Out:
#         3o. Agrupamento            4o. Agrupamento  \
# 0     Cartão de Crédito   Cart Hipercard Pagseguro
# 1     Cartão de Crédito   Cart Hipercard Pagseguro
# 2      Cartão de Débito     Cart Maestro Pagseguro
# 3      Cartão de Débito     Cart Maestro Pagseguro
# 4              Dinheiro  Carteira Cobrança Simples
# ...                 ...                        ...
# 1907           Dinheiro  Carteira Cobrança Simples
# 1908           Dinheiro  Carteira Cobrança Simples
# 1909           Dinheiro  Carteira Cobrança Simples
# 1910           Dinheiro  Carteira Cobrança Simples
# 1911           Dinheiro  Carteira Cobrança Simples
#
#                          Descrição           Cliente     Emissão   Valor  \
# 0     630276895-2/2, 630276895-1/2               NaN  10/03/2022   53.46
# 1     635209191-2/2, 635209191-1/2               NaN  16/03/2022  194.94
# 2                    633042330-1/1               NaN  13/03/2022  101.00
# 3                    635209553-1/1               NaN  16/03/2022  500.00
# 4                    627764966-1/1               NaN  01/03/2022  604.00
# ...                            ...               ...         ...     ...
# 1907             RC 1062 / RC 1062  Consumidor Final  24/03/2022   10.00
# 1908             RC 1064 / RC 1064  Consumidor Final  26/03/2022   15.00
# 1909             RC 1066 / RC 1066  Consumidor Final  26/03/2022   10.00
# 1910             RC 1213 / RC 1213  Consumidor Final  30/03/2022   30.00
# 1911             RC 1215 / RC 1215  Consumidor Final  31/03/2022   20.00
#
#      DEBITO
# 0     10221
# 1     10221
# 2     10221
# 3     10221
# 4      None
# ...     ...
# 1907   None
# 1908   None
# 1909   None
# 1910   None
# 1911   None
#
# [1912 rows x 7 columns]

# %%
# 3 agrupamento
for index, row in mapadecaixa.iterrows():
    if row['3o. Agrupamento'] == 'Duplicata':
        mapadecaixa.loc[index, 'DEBITO'] = '10265'
    elif row['3o. Agrupamento'] == 'Crédito Bancário':
        mapadecaixa.loc[index, 'DEBITO'] = '10265'
    elif row['3o. Agrupamento'] == 'Cheque à vista':
        mapadecaixa.loc[index, 'DEBITO'] = '10267'

# mapadecaixa.head(38)
mapadecaixa

# %%
#--- 3 agrupamento
# quando for DUPLICATA a conta "DEBITO" = 10265
# quando for CRÉDITO BANCÁRIO a conta "DEBITO" = 10265
# quando for CHEQUE A VISTA a conta "DEBITO" = 10267
for index, row in mapadecaixa.iterrows():
    if row['3o. Agrupamento'] == 'Duplicata':
        mapadecaixa.loc[index, 'DEBITO'] = '10265'
    if row['3o. Agrupamento'] == 'Crédito Bancário':
        mapadecaixa.loc[index, 'DEBITO'] = '10265'
    if row['3o. Agrupamento'] == 'Cheque à vista':
        mapadecaixa.loc[index, 'DEBITO'] = '10267'

mapadecaixa.head(38)
# mapadecaixa.loc['3o. Agrupamento'] == 'Duplicata'

# %%
# mapadecaixa[mapadecaixa['3o. Agrupamento'].str.startswith('Duplicata')] and mapadecaixa[mapadecaixa['3o. Agrupamento'].str.startswith('Crédito Bancário')],
# mapadecaixa[mapadecaixa['3o. Agrupamento'].str.startswith('Cheque à vista')]

# %%
# ----mapadecaixa.head(38)

# Exibe valores que contenha 'RC'
# mapadecaixa[mapadecaixa['Descrição'].str.contains('RC')]

# Exibe apenas valores que começa com 'RC'
# mapadecaixa[mapadecaixa['3o. Agrupamento'].str.startswith('Duplicata')]
mapadecaixa[mapadecaixa['3o. Agrupamento'].str.startswith('Cheque à vista')]

# %%
# 4 agrupamento
for index, row in mapadecaixa.iterrows():
    if row['4o. Agrupamento'] == 'Carteira Cobrança Simples':
        mapadecaixa.loc[index, 'DEBITO'] = '45534'
    elif row['4o. Agrupamento'] == 'Cart Credito Garantia':
        mapadecaixa.loc[index, 'DEBITO'] = '344640'

mapadecaixa
# Out:
#         3o. Agrupamento            4o. Agrupamento  \
# 0     Cartão de Crédito   Cart Hipercard Pagseguro
# 1     Cartão de Crédito   Cart Hipercard Pagseguro
# 2      Cartão de Débito     Cart Maestro Pagseguro
# 3      Cartão de Débito     Cart Maestro Pagseguro
# 4              Dinheiro  Carteira Cobrança Simples
# ...                 ...                        ...
# 1907           Dinheiro  Carteira Cobrança Simples
# 1908           Dinheiro  Carteira Cobrança Simples
# 1909           Dinheiro  Carteira Cobrança Simples
# 1910           Dinheiro  Carteira Cobrança Simples
# 1911           Dinheiro  Carteira Cobrança Simples
#
#                          Descrição           Cliente     Emissão   Valor  \
# 0     630276895-2/2, 630276895-1/2               NaN  10/03/2022   53.46
# 1     635209191-2/2, 635209191-1/2               NaN  16/03/2022  194.94
# 2                    633042330-1/1               NaN  13/03/2022  101.00
# 3                    635209553-1/1               NaN  16/03/2022  500.00
# 4                    627764966-1/1               NaN  01/03/2022  604.00
# ...                            ...               ...         ...     ...
# 1907             RC 1062 / RC 1062  Consumidor Final  24/03/2022   10.00
# 1908             RC 1064 / RC 1064  Consumidor Final  26/03/2022   15.00
# 1909             RC 1066 / RC 1066  Consumidor Final  26/03/2022   10.00
# 1910             RC 1213 / RC 1213  Consumidor Final  30/03/2022   30.00
# 1911             RC 1215 / RC 1215  Consumidor Final  31/03/2022   20.00
#
#      DEBITO
# 0     10221
# 1     10221
# 2     10221
# 3     10221
# 4     45534
# ...     ...
# 1907  45534
# 1908  45534
# 1909  45534
# 1910  45534
# 1911  45534
#
# [1912 rows x 7 columns]

# %%
#---- 4 agrupamento
# quando for "Carteira Cobrança Simples" a conta "DEBITO" = 45534
# quando for "Cart Credito Garantia" a conta "DEBITO" = 344640
for index, row in mapadecaixa.iterrows():
    if row['4o. Agrupamento'] == 'Carteira Cobrança Simples':
        mapadecaixa.loc[index, 'DEBITO'] = '45534'
    if row['4o. Agrupamento'] == 'Cart Credito Garantia':
        mapadecaixa.loc[index, 'DEBITO'] = '344640'

# %%
mapadecaixa.head(38)

# %%
# CRIANDO A COLUNA 'CREDITO'
mapadecaixa['CREDITO'] = '10164' 

mapadecaixa
# Out:
#         3o. Agrupamento            4o. Agrupamento  \
# 0     Cartão de Crédito   Cart Hipercard Pagseguro
# 1     Cartão de Crédito   Cart Hipercard Pagseguro
# 2      Cartão de Débito     Cart Maestro Pagseguro
# 3      Cartão de Débito     Cart Maestro Pagseguro
# 4              Dinheiro  Carteira Cobrança Simples
# ...                 ...                        ...
# 1907           Dinheiro  Carteira Cobrança Simples
# 1908           Dinheiro  Carteira Cobrança Simples
# 1909           Dinheiro  Carteira Cobrança Simples
# 1910           Dinheiro  Carteira Cobrança Simples
# 1911           Dinheiro  Carteira Cobrança Simples
#
#                          Descrição           Cliente     Emissão   Valor  \
# 0     630276895-2/2, 630276895-1/2               NaN  10/03/2022   53.46
# 1     635209191-2/2, 635209191-1/2               NaN  16/03/2022  194.94
# 2                    633042330-1/1               NaN  13/03/2022  101.00
# 3                    635209553-1/1               NaN  16/03/2022  500.00
# 4                    627764966-1/1               NaN  01/03/2022  604.00
# ...                            ...               ...         ...     ...
# 1907             RC 1062 / RC 1062  Consumidor Final  24/03/2022   10.00
# 1908             RC 1064 / RC 1064  Consumidor Final  26/03/2022   15.00
# 1909             RC 1066 / RC 1066  Consumidor Final  26/03/2022   10.00
# 1910             RC 1213 / RC 1213  Consumidor Final  30/03/2022   30.00
# 1911             RC 1215 / RC 1215  Consumidor Final  31/03/2022   20.00
#
#      DEBITO CREDITO
# 0     10221   10164
# 1     10221   10164
# 2     10221   10164
# 3     10221   10164
# 4     45534   10164
# ...     ...     ...
# 1907  45534   10164
# 1908  45534   10164
# 1909  45534   10164
# 1910  45534   10164
# 1911  45534   10164
#
# [1912 rows x 8 columns]

# %%
#---Verificando o tipo da coluna
mapadecaixa.dtypes

# %%
#---Alterando o tipo de dados da coluna
mapadecaixa['Descrição'] = mapadecaixa['Descrição'].astype('string')

# %%
#---Verificando o tipo da coluna
mapadecaixa.dtypes

# %%
# DESCRIÇÃO
# quando na DESCRIÇÃO conter "RC*" a conta a CRÉDITO = 31472
for index, row in mapadecaixa.iterrows():
    # if row['Descrição'] == 'RC':
    # if mapadecaixa.loc[mapadecaixa['Descrição'].str.contains('RC', case=False, na=False)]:
    # if mapadecaixa[mapadecaixa['Descrição'].str.contains('RC')].any():
    # if mapadecaixa.index['Descrição'].str.contains('RC'):
    # if mapadecaixa['Descrição'].str.contains('RC').all():
    # if row['Descrição'].str.contains('RC'):
    # if "RC " in mapadecaixa["Descrição"].values:
    if row['Descrição'].startswith('RC'):
    # if row['Descrição'].str.match('RC'):
    # if row[mapadecaixa[mapadecaixa['Descrição'].str.startswith('RC')]]:
        mapadecaixa.loc[index, 'CREDITO'] = '31472'

mapadecaixa
# Out:
#         3o. Agrupamento            4o. Agrupamento  \
# 0     Cartão de Crédito   Cart Hipercard Pagseguro
# 1     Cartão de Crédito   Cart Hipercard Pagseguro
# 2      Cartão de Débito     Cart Maestro Pagseguro
# 3      Cartão de Débito     Cart Maestro Pagseguro
# 4              Dinheiro  Carteira Cobrança Simples
# ...                 ...                        ...
# 1907           Dinheiro  Carteira Cobrança Simples
# 1908           Dinheiro  Carteira Cobrança Simples
# 1909           Dinheiro  Carteira Cobrança Simples
# 1910           Dinheiro  Carteira Cobrança Simples
# 1911           Dinheiro  Carteira Cobrança Simples
#
#                          Descrição           Cliente     Emissão   Valor  \
# 0     630276895-2/2, 630276895-1/2               NaN  10/03/2022   53.46
# 1     635209191-2/2, 635209191-1/2               NaN  16/03/2022  194.94
# 2                    633042330-1/1               NaN  13/03/2022  101.00
# 3                    635209553-1/1               NaN  16/03/2022  500.00
# 4                    627764966-1/1               NaN  01/03/2022  604.00
# ...                            ...               ...         ...     ...
# 1907             RC 1062 / RC 1062  Consumidor Final  24/03/2022   10.00
# 1908             RC 1064 / RC 1064  Consumidor Final  26/03/2022   15.00
# 1909             RC 1066 / RC 1066  Consumidor Final  26/03/2022   10.00
# 1910             RC 1213 / RC 1213  Consumidor Final  30/03/2022   30.00
# 1911             RC 1215 / RC 1215  Consumidor Final  31/03/2022   20.00
#
#      DEBITO CREDITO
# 0     10221   10164
# 1     10221   10164
# 2     10221   10164
# 3     10221   10164
# 4     45534   10164
# ...     ...     ...
# 1907  45534   31472
# 1908  45534   31472
# 1909  45534   31472
# 1910  45534   31472
# 1911  45534   31472
#
# [1912 rows x 8 columns]

# %%
#----Exibe valores que contenha 'RC'
mapadecaixa[mapadecaixa['Descrição'].str.contains('RC')]

# Exibe apenas valores que começa com 'RC'
# mapadecaixa[mapadecaixa['Descrição'].str.startswith('RC')]

# %%
# Criando nova coluna
mapadecaixa['NEWCOLUN'] = ''
for index, row in mapadecaixa.iterrows():
    if row['3o. Agrupamento'] == 'Duplicata':
        mapadecaixa.loc[index,'NEWCOLUN'] =  str(mapadecaixa.loc[index,'3o. Agrupamento']) + ' - ' + str(mapadecaixa.loc[index,'Cliente'])
    elif row['3o. Agrupamento'] == 'Crédito Bancário':
        mapadecaixa.loc[index,'NEWCOLUN'] =  str(mapadecaixa.loc[index,'3o. Agrupamento']) + ' - ' + str(mapadecaixa.loc[index,'Cliente'])
    elif row['3o. Agrupamento'] == 'Cheque à vista':
        mapadecaixa.loc[index,'NEWCOLUN'] =  str(mapadecaixa.loc[index,'3o. Agrupamento']) + ' - ' + str(mapadecaixa.loc[index,'Cliente'])

mapadecaixa

# %%
#---- Criando nova coluna
mapadecaixa['NEWCOLUN'] = ''
# onde na coluna '3o. Agrupamento' for = 'Duplicata' faça '3o. Agrupamento' + 'Cliente'
# onde na coluna '3o. Agrupamento' for = 'Crédito bancario' faça '3o. Agrupamento' + 'Cliente'
# onde na coluna '3o. Agrupamento' for = 'Cheque à vista' faça '3o. Agrupamento' + 'Cliente'
# Fazendo a iteração:
for index, row in mapadecaixa.iterrows():
    if row['3o. Agrupamento'] == 'Duplicata':
        mapadecaixa.loc[index,'NEWCOLUN'] =  str(mapadecaixa.loc[index,'3o. Agrupamento']) + ' - ' + str(mapadecaixa.loc[index,'Cliente'])
    if row['3o. Agrupamento'] == 'Crédito Bancário':
        mapadecaixa.loc[index,'NEWCOLUN'] =  str(mapadecaixa.loc[index,'3o. Agrupamento']) + ' - ' + str(mapadecaixa.loc[index,'Cliente'])
    if row['3o. Agrupamento'] == 'Cheque à vista':
        mapadecaixa.loc[index,'NEWCOLUN'] =  str(mapadecaixa.loc[index,'3o. Agrupamento']) + ' - ' + str(mapadecaixa.loc[index,'Cliente'])

# %%
# mapadecaixa.head()
# mapadecaixa.head(38)
#----Exibe valores que contenha 'RC'
mapadecaixa[mapadecaixa['3o. Agrupamento'].str.contains('Duplicata')]

# %%
#----Ordena todas as linhas do DataFrame do maior para o menor
# O ignore_index=True permanece com o indece sempre em ordem independente se o ASCENDING seja FALSE ou TRUE.
# O na_position='first' ordena as linhas vázias/NULAS nas primeiras posições.
# O inplace=True grava a mudança no DataFrame
mapadecaixa.sort_values(['4o. Agrupamento', 'Descrição', 'Cliente', 'Emissão', 'Valor'], ascending=False, ignore_index=True, na_position='first')

# %%
# mapadecaixa.head()
mapadecaixa
# Out:
#         3o. Agrupamento            4o. Agrupamento  \
# 0     Cartão de Crédito   Cart Hipercard Pagseguro
# 1     Cartão de Crédito   Cart Hipercard Pagseguro
# 2      Cartão de Débito     Cart Maestro Pagseguro
# 3      Cartão de Débito     Cart Maestro Pagseguro
# 4              Dinheiro  Carteira Cobrança Simples
# ...                 ...                        ...
# 1907           Dinheiro  Carteira Cobrança Simples
# 1908           Dinheiro  Carteira Cobrança Simples
# 1909           Dinheiro  Carteira Cobrança Simples
# 1910           Dinheiro  Carteira Cobrança Simples
# 1911           Dinheiro  Carteira Cobrança Simples
#
#                          Descrição           Cliente     Emissão   Valor  \
# 0     630276895-2/2, 630276895-1/2               NaN  10/03/2022   53.46
# 1     635209191-2/2, 635209191-1/2               NaN  16/03/2022  194.94
# 2                    633042330-1/1               NaN  13/03/2022  101.00
# 3                    635209553-1/1               NaN  16/03/2022  500.00
# 4                    627764966-1/1               NaN  01/03/2022  604.00
# ...                            ...               ...         ...     ...
# 1907             RC 1062 / RC 1062  Consumidor Final  24/03/2022   10.00
# 1908             RC 1064 / RC 1064  Consumidor Final  26/03/2022   15.00
# 1909             RC 1066 / RC 1066  Consumidor Final  26/03/2022   10.00
# 1910             RC 1213 / RC 1213  Consumidor Final  30/03/2022   30.00
# 1911             RC 1215 / RC 1215  Consumidor Final  31/03/2022   20.00
#
#      DEBITO CREDITO NEWCOLUN
# 0     10221   10164
# 1     10221   10164
# 2     10221   10164
# 3     10221   10164
# 4     45534   10164
# ...     ...     ...      ...
# 1907  45534   31472
# 1908  45534   31472
# 1909  45534   31472
# 1910  45534   31472
# 1911  45534   31472
#
# [1912 rows x 9 columns]

# %%
#---- verificando o tipo de dados das colunas
mapadecaixa.dtypes

# %%
#---Alterando o tipo de dados da coluna
mapadecaixa['4o. Agrupamento'] = mapadecaixa['4o. Agrupamento'].astype('string')

# %%
#---- verificando o tipo de dados das colunas
mapadecaixa.dtypes

# %%
# O (.str.replace) pra retirar os - e 
# mapadecaixa[['4o. Agrupamento','DEBITO']] = mapadecaixa['4o. Agrupamento'].str.split(';', expand=True)

# mapadecaixa.head(38)

# %%
# mapadecaixa
mapadecaixa.head(40)

# %%
# CRIANDO A COLUNA 'FILIAL'
mapadecaixa['FILIAL'] = ''

mapadecaixa

# %%
# MESCLANDO OS CONTEÚDO DA COLUNA 'HISTORIOC', 'NEWCOLUN' e 'Descrição'
# mapadecaixa['HISTORICO'] = '10.01'+ "," + mapadecaixa['4o. Agrupamento']+ "," + mapadecaixa['Cliente']+ "," + mapadecaixa['Descrição']
mapadecaixa['HISTORICO'] = '10.01'+ "," + mapadecaixa['NEWCOLUN']+ "," + mapadecaixa['Descrição']

mapadecaixa
# Out:
#         3o. Agrupamento            4o. Agrupamento  \
# 0     Cartão de Crédito   Cart Hipercard Pagseguro
# 1     Cartão de Crédito   Cart Hipercard Pagseguro
# 2      Cartão de Débito     Cart Maestro Pagseguro
# 3      Cartão de Débito     Cart Maestro Pagseguro
# 4              Dinheiro  Carteira Cobrança Simples
# ...                 ...                        ...
# 1907           Dinheiro  Carteira Cobrança Simples
# 1908           Dinheiro  Carteira Cobrança Simples
# 1909           Dinheiro  Carteira Cobrança Simples
# 1910           Dinheiro  Carteira Cobrança Simples
# 1911           Dinheiro  Carteira Cobrança Simples
#
#                          Descrição           Cliente     Emissão   Valor  \
# 0     630276895-2/2, 630276895-1/2               NaN  10/03/2022   53.46
# 1     635209191-2/2, 635209191-1/2               NaN  16/03/2022  194.94
# 2                    633042330-1/1               NaN  13/03/2022  101.00
# 3                    635209553-1/1               NaN  16/03/2022  500.00
# 4                    627764966-1/1               NaN  01/03/2022  604.00
# ...                            ...               ...         ...     ...
# 1907             RC 1062 / RC 1062  Consumidor Final  24/03/2022   10.00
# 1908             RC 1064 / RC 1064  Consumidor Final  26/03/2022   15.00
# 1909             RC 1066 / RC 1066  Consumidor Final  26/03/2022   10.00
# 1910             RC 1213 / RC 1213  Consumidor Final  30/03/2022   30.00
# 1911             RC 1215 / RC 1215  Consumidor Final  31/03/2022   20.00
#
#      DEBITO CREDITO NEWCOLUN FILIAL                            HISTORICO
# 0     10221   10164                  10.01,,630276895-2/2, 630276895-1/2
# 1     10221   10164                  10.01,,635209191-2/2, 635209191-1/2
# 2     10221   10164                                 10.01,,633042330-1/1
# 3     10221   10164                                 10.01,,635209553-1/1
# 4     45534   10164                                 10.01,,627764966-1/1
# ...     ...     ...      ...    ...                                  ...
# 1907  45534   31472                             10.01,,RC 1062 / RC 1062
# 1908  45534   31472                             10.01,,RC 1064 / RC 1064
# 1909  45534   31472                             10.01,,RC 1066 / RC 1066
# 1910  45534   31472                             10.01,,RC 1213 / RC 1213
# 1911  45534   31472                             10.01,,RC 1215 / RC 1215
#
# [1912 rows x 11 columns]

# %%
# SUBSTITUIR pontos (.) por vírgulas (,) 
# mapadecaixa['HISTORICO'] = mapadecaixa['HISTORICO'].apply(lambda x: float(x.replace(".","").replace(",",".")))
# mapadecaixa = mapadecaixa.replace({',': ''}, regex=True)
mapadecaixa['HISTORICO'] = mapadecaixa['HISTORICO'].astype(str)
mapadecaixa['HISTORICO'] = mapadecaixa['HISTORICO'].str.replace(',,', ',')
# mapadecaixa['HISTORICO'] = mapadecaixa['HISTORICO'].str.replace('"', '') # Retira as aspas.

mapadecaixa

# %%
# CAPTULANDO TODA COLUNA 'HISTORICO'
mapadecaixa['HISTORICO'] = mapadecaixa['HISTORICO'].str.upper()

mapadecaixa
# Out:
#         3o. Agrupamento            4o. Agrupamento  \
# 0     Cartão de Crédito   Cart Hipercard Pagseguro
# 1     Cartão de Crédito   Cart Hipercard Pagseguro
# 2      Cartão de Débito     Cart Maestro Pagseguro
# 3      Cartão de Débito     Cart Maestro Pagseguro
# 4              Dinheiro  Carteira Cobrança Simples
# ...                 ...                        ...
# 1907           Dinheiro  Carteira Cobrança Simples
# 1908           Dinheiro  Carteira Cobrança Simples
# 1909           Dinheiro  Carteira Cobrança Simples
# 1910           Dinheiro  Carteira Cobrança Simples
# 1911           Dinheiro  Carteira Cobrança Simples
#
#                          Descrição           Cliente     Emissão   Valor  \
# 0     630276895-2/2, 630276895-1/2               NaN  10/03/2022   53.46
# 1     635209191-2/2, 635209191-1/2               NaN  16/03/2022  194.94
# 2                    633042330-1/1               NaN  13/03/2022  101.00
# 3                    635209553-1/1               NaN  16/03/2022  500.00
# 4                    627764966-1/1               NaN  01/03/2022  604.00
# ...                            ...               ...         ...     ...
# 1907             RC 1062 / RC 1062  Consumidor Final  24/03/2022   10.00
# 1908             RC 1064 / RC 1064  Consumidor Final  26/03/2022   15.00
# 1909             RC 1066 / RC 1066  Consumidor Final  26/03/2022   10.00
# 1910             RC 1213 / RC 1213  Consumidor Final  30/03/2022   30.00
# 1911             RC 1215 / RC 1215  Consumidor Final  31/03/2022   20.00
#
#      DEBITO CREDITO NEWCOLUN FILIAL                           HISTORICO
# 0     10221   10164                  10.01,630276895-2/2, 630276895-1/2
# 1     10221   10164                  10.01,635209191-2/2, 635209191-1/2
# 2     10221   10164                                 10.01,633042330-1/1
# 3     10221   10164                                 10.01,635209553-1/1
# 4     45534   10164                                 10.01,627764966-1/1
# ...     ...     ...      ...    ...                                 ...
# 1907  45534   31472                             10.01,RC 1062 / RC 1062
# 1908  45534   31472                             10.01,RC 1064 / RC 1064
# 1909  45534   31472                             10.01,RC 1066 / RC 1066
# 1910  45534   31472                             10.01,RC 1213 / RC 1213
# 1911  45534   31472                             10.01,RC 1215 / RC 1215
#
# [1912 rows x 11 columns]

# %%
# CAPTULANDO TODA COLUNA 'HISTORICO'
mapadecaixa['4o. Agrupamento'] = mapadecaixa['4o. Agrupamento'].str.upper()

mapadecaixa
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    <a href='file:///c%3A/Users/lmiguel/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/indexes/base.py?line=3619'>3620</a> try:
# -> <a href='file:///c%3A/Users/lmiguel/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/indexes/base.py?line=3620'>3621</a>     return self._engine.get_loc(casted_key)
#    <a href='file:///c%3A/Users/lmiguel/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/indexes/base.py?line=3621'>3622</a> except KeyError as err:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '4o.Agrupamento'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# c:\BKP DESKTOP\MAPA DE CAIXA\csv - mapadecaixa\app2copy.ipynb Cell 41' in <module>
#       <a href='vscode-notebook-cell:/c%3A/BKP%20DESKTOP/MAPA%20DE%20CAIXA/csv%20-%20mapadecaixa/app2copy.ipynb#ch0000057?line=0'>1</a> # CAPTULANDO TODA COLUNA 'HISTORICO'
# ----> <a href='vscode-notebook-cell:/c%3A/BKP%20DESKTOP/MAPA%20DE%20CAIXA/csv%20-%20mapadecaixa/app2copy.ipynb#ch0000057?line=1'>2</a> mapadecaixa['4o. Agrupamento'] = mapadecaixa['4o.Agrupamento'].str.upper()
#       <a href='vscode-notebook-cell:/c%3A/BKP%20DESKTOP/MAPA%20DE%20CAIXA/csv%20-%20mapadecaixa/app2copy.ipynb#ch0000057?line=3'>4</a> mapadecaixa
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    <a href='file:///c%3A/Users/lmiguel/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=3502'>3503</a> if self.columns.nlevels > 1:
#    <a href='file:///c%3A/Users/lmiguel/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=3503'>3504</a>     return self._getitem_multilevel(key)
# -> <a href='file:///c%3A/Users/lmiguel/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=3504'>3505</a> indexer = self.columns.get_loc(key)
#    <a href='file:///c%3A/Users/lmiguel/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=3505'>3506</a> if is_integer(indexer):
#    <a href='file:///c%3A/Users/lmiguel/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=3506'>3507</a>     indexer = [indexer]
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    <a href='file:///c%3A/Users/lmiguel/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/indexes/base.py?line=3620'>3621</a>     return self._engine.get_loc(casted_key)
#    <a href='file:///c%3A/Users/lmiguel/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/indexes/base.py?line=3621'>3622</a> except KeyError as err:
# -> <a href='file:///c%3A/Users/lmiguel/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/indexes/base.py?line=3622'>3623</a>     raise KeyError(key) from err
#    <a href='file:///c%3A/Users/lmiguel/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/indexes/base.py?line=3623'>3624</a> except TypeError:
#    <a href='file:///c%3A/Users/lmiguel/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/indexes/base.py?line=3624'>3625</a>     # If we have a listlike key, _check_indexing_error will raise
#    <a href='file:///c%3A/Users/lmiguel/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/indexes/base.py?line=3625'>3626</a>     #  InvalidIndexError. Otherwise we fall through and re-raise
#    <a href='file:///c%3A/Users/lmiguel/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/indexes/base.py?line=3626'>3627</a>     #  the TypeError.
#    <a href='file:///c%3A/Users/lmiguel/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/indexes/base.py?line=3627'>3628</a>     self._check_indexing_error(key)
#
# KeyError: '4o.Agrupamento'

# %%
# mapadecaixa
# mapadecaixa.head(40)
mapadecaixa.head()
# Out:
#      3o. Agrupamento            4o. Agrupamento                     Descrição  \
# 0  Cartão de Crédito   CART HIPERCARD PAGSEGURO  630276895-2/2, 630276895-1/2
# 1  Cartão de Crédito   CART HIPERCARD PAGSEGURO  635209191-2/2, 635209191-1/2
# 2   Cartão de Débito     CART MAESTRO PAGSEGURO                 633042330-1/1
# 3   Cartão de Débito     CART MAESTRO PAGSEGURO                 635209553-1/1
# 4           Dinheiro  CARTEIRA COBRANÇA SIMPLES                 627764966-1/1
#
#   Cliente     Emissão   Valor DEBITO CREDITO NEWCOLUN FILIAL  \
# 0     NaN  10/03/2022   53.46  10221   10164
# 1     NaN  16/03/2022  194.94  10221   10164
# 2     NaN  13/03/2022  101.00  10221   10164
# 3     NaN  16/03/2022  500.00  10221   10164
# 4     NaN  01/03/2022  604.00  45534   10164
#
#                             HISTORICO
# 0  10.01,630276895-2/2, 630276895-1/2
# 1  10.01,635209191-2/2, 635209191-1/2
# 2                 10.01,633042330-1/1
# 3                 10.01,635209553-1/1
# 4                 10.01,627764966-1/1

# %%
# EXCLUÍNDO COLUNA
# mapadecaixa = mapadecaixa.drop('3o. Agrupamento', axis=1)
# mapadecaixa = mapadecaixa.drop('4o. Agrupamento', axis=1)
# mapadecaixa = mapadecaixa.drop('Descrição', axis=1)
# mapadecaixa = mapadecaixa.drop('Cliente', axis=1)
# mapadecaixa = mapadecaixa.drop(['3o. Agrupamento','4o. Agrupamento','Descrição','Cliente', 'NEWCOLUN'], axis=1, inplace=True)
mapadecaixa = mapadecaixa.drop(['3o. Agrupamento','Descrição','Cliente', 'NEWCOLUN'], axis=1)

mapadecaixa
# Out:
#                 4o. Agrupamento     Emissão   Valor DEBITO CREDITO FILIAL  \
# 0      CART HIPERCARD PAGSEGURO  10/03/2022   53.46  10221   10164
# 1      CART HIPERCARD PAGSEGURO  16/03/2022  194.94  10221   10164
# 2        CART MAESTRO PAGSEGURO  13/03/2022  101.00  10221   10164
# 3        CART MAESTRO PAGSEGURO  16/03/2022  500.00  10221   10164
# 4     CARTEIRA COBRANÇA SIMPLES  01/03/2022  604.00  45534   10164
# ...                         ...         ...     ...    ...     ...    ...
# 1907  CARTEIRA COBRANÇA SIMPLES  24/03/2022   10.00  45534   31472
# 1908  CARTEIRA COBRANÇA SIMPLES  26/03/2022   15.00  45534   31472
# 1909  CARTEIRA COBRANÇA SIMPLES  26/03/2022   10.00  45534   31472
# 1910  CARTEIRA COBRANÇA SIMPLES  30/03/2022   30.00  45534   31472
# 1911  CARTEIRA COBRANÇA SIMPLES  31/03/2022   20.00  45534   31472
#
#                                HISTORICO
# 0     10.01,630276895-2/2, 630276895-1/2
# 1     10.01,635209191-2/2, 635209191-1/2
# 2                    10.01,633042330-1/1
# 3                    10.01,635209553-1/1
# 4                    10.01,627764966-1/1
# ...                                  ...
# 1907             10.01,RC 1062 / RC 1062
# 1908             10.01,RC 1064 / RC 1064
# 1909             10.01,RC 1066 / RC 1066
# 1910             10.01,RC 1213 / RC 1213
# 1911             10.01,RC 1215 / RC 1215
#
# [1912 rows x 7 columns]

# %%
# RENOMEAR COLUNAS
# colunas = {'4o. Agrupamento':'4AGRUPAMENTO','Descrição':'DESCRIÇÃO','Cliente':'CLIENTE','Emissão':'DATA','Valor':'VALOR'}
colunas = {'Emissão':'DATA','Valor':'VALOR'}
mapadecaixa.rename(columns = colunas, inplace=True) 

mapadecaixa
# Out:
#                 4o. Agrupamento        DATA   VALOR DEBITO CREDITO FILIAL  \
# 0      CART HIPERCARD PAGSEGURO  10/03/2022   53.46  10221   10164
# 1      CART HIPERCARD PAGSEGURO  16/03/2022  194.94  10221   10164
# 2        CART MAESTRO PAGSEGURO  13/03/2022  101.00  10221   10164
# 3        CART MAESTRO PAGSEGURO  16/03/2022  500.00  10221   10164
# 4     CARTEIRA COBRANÇA SIMPLES  01/03/2022  604.00  45534   10164
# ...                         ...         ...     ...    ...     ...    ...
# 1907  CARTEIRA COBRANÇA SIMPLES  24/03/2022   10.00  45534   31472
# 1908  CARTEIRA COBRANÇA SIMPLES  26/03/2022   15.00  45534   31472
# 1909  CARTEIRA COBRANÇA SIMPLES  26/03/2022   10.00  45534   31472
# 1910  CARTEIRA COBRANÇA SIMPLES  30/03/2022   30.00  45534   31472
# 1911  CARTEIRA COBRANÇA SIMPLES  31/03/2022   20.00  45534   31472
#
#                                HISTORICO
# 0     10.01,630276895-2/2, 630276895-1/2
# 1     10.01,635209191-2/2, 635209191-1/2
# 2                    10.01,633042330-1/1
# 3                    10.01,635209553-1/1
# 4                    10.01,627764966-1/1
# ...                                  ...
# 1907             10.01,RC 1062 / RC 1062
# 1908             10.01,RC 1064 / RC 1064
# 1909             10.01,RC 1066 / RC 1066
# 1910             10.01,RC 1213 / RC 1213
# 1911             10.01,RC 1215 / RC 1215
#
# [1912 rows x 7 columns]

# %%
# REORDENANDO COLUNAS
new_ordem_colls = ['FILIAL', 'DATA', 'DEBITO', 'CREDITO', 'VALOR', '4o. Agrupamento', 'HISTORICO']
mapadecaixa = mapadecaixa[new_ordem_colls]

mapadecaixa
# Out:
#      FILIAL        DATA DEBITO CREDITO   VALOR            4o. Agrupamento  \
# 0            10/03/2022  10221   10164   53.46   CART HIPERCARD PAGSEGURO
# 1            16/03/2022  10221   10164  194.94   CART HIPERCARD PAGSEGURO
# 2            13/03/2022  10221   10164  101.00     CART MAESTRO PAGSEGURO
# 3            16/03/2022  10221   10164  500.00     CART MAESTRO PAGSEGURO
# 4            01/03/2022  45534   10164  604.00  CARTEIRA COBRANÇA SIMPLES
# ...     ...         ...    ...     ...     ...                        ...
# 1907         24/03/2022  45534   31472   10.00  CARTEIRA COBRANÇA SIMPLES
# 1908         26/03/2022  45534   31472   15.00  CARTEIRA COBRANÇA SIMPLES
# 1909         26/03/2022  45534   31472   10.00  CARTEIRA COBRANÇA SIMPLES
# 1910         30/03/2022  45534   31472   30.00  CARTEIRA COBRANÇA SIMPLES
# 1911         31/03/2022  45534   31472   20.00  CARTEIRA COBRANÇA SIMPLES
#
#                                HISTORICO
# 0     10.01,630276895-2/2, 630276895-1/2
# 1     10.01,635209191-2/2, 635209191-1/2
# 2                    10.01,633042330-1/1
# 3                    10.01,635209553-1/1
# 4                    10.01,627764966-1/1
# ...                                  ...
# 1907             10.01,RC 1062 / RC 1062
# 1908             10.01,RC 1064 / RC 1064
# 1909             10.01,RC 1066 / RC 1066
# 1910             10.01,RC 1213 / RC 1213
# 1911             10.01,RC 1215 / RC 1215
#
# [1912 rows x 7 columns]

# %%
#---- SUBSTITUINDO OS VALORES 'NaN' e 'None', VALORES NULOS OU EMBRANCO
# mapadecaixa['DEBITO'].fillna(1111, inplace=True) # O "inplace=True" grava no dataframe. Faz a alteração apenas na coluna 'DEBITO'.
mapadecaixa.fillna(1111, inplace=True) # O "inplace=True" grava no dataframe. Faz a alteração em todo DATAFRAMA.

# %%
#---- QUANTOS DADOS FALTANTES TEM NAS COLUNAS
mapadecaixa.isnull().sum()

# EXIBIR LINHAS EM BRANCO
mapadecaixa[mapadecaixa['DEBITO'].isnull()]

# %%
# mapadecaixa
mapadecaixa.head(40)

# %%
#----Ordena todas as linhas do DataFrame do maior para o menor
# O ignore_index=True permanece com o indece sempre em ordem independente se o ASCENDING seja FALSE ou TRUE.
# O na_position='first' ordena as linhas vázias/NULAS nas primeiras posições.
# O inplace=True grava a mudança no DataFrame
## mapadecaixa.sort_values(['4o. Agrupamento', 'Descrição', 'Cliente', 'Emissão', 'Valor'], ascending=False, ignore_index=True, na_position='first', inplace=True)
mapadecaixa.sort_values(['4o. Agrupamento', 'Descrição', 'Cliente', 'Emissão', 'Valor'], ascending=False, ignore_index=True, na_position='first')

# %%
# DIGITE A FILIAL
filial = input("Digite a Filial: ")
mapadecaixa['FILIAL'] = filial

mapadecaixa
# Out:
#      FILIAL        DATA DEBITO CREDITO   VALOR            4o. Agrupamento  \
# 0        87  10/03/2022  10221   10164   53.46   CART HIPERCARD PAGSEGURO
# 1        87  16/03/2022  10221   10164  194.94   CART HIPERCARD PAGSEGURO
# 2        87  13/03/2022  10221   10164  101.00     CART MAESTRO PAGSEGURO
# 3        87  16/03/2022  10221   10164  500.00     CART MAESTRO PAGSEGURO
# 4        87  01/03/2022  45534   10164  604.00  CARTEIRA COBRANÇA SIMPLES
# ...     ...         ...    ...     ...     ...                        ...
# 1907     87  24/03/2022  45534   31472   10.00  CARTEIRA COBRANÇA SIMPLES
# 1908     87  26/03/2022  45534   31472   15.00  CARTEIRA COBRANÇA SIMPLES
# 1909     87  26/03/2022  45534   31472   10.00  CARTEIRA COBRANÇA SIMPLES
# 1910     87  30/03/2022  45534   31472   30.00  CARTEIRA COBRANÇA SIMPLES
# 1911     87  31/03/2022  45534   31472   20.00  CARTEIRA COBRANÇA SIMPLES
#
#                                HISTORICO
# 0     10.01,630276895-2/2, 630276895-1/2
# 1     10.01,635209191-2/2, 635209191-1/2
# 2                    10.01,633042330-1/1
# 3                    10.01,635209553-1/1
# 4                    10.01,627764966-1/1
# ...                                  ...
# 1907             10.01,RC 1062 / RC 1062
# 1908             10.01,RC 1064 / RC 1064
# 1909             10.01,RC 1066 / RC 1066
# 1910             10.01,RC 1213 / RC 1213
# 1911             10.01,RC 1215 / RC 1215
#
# [1912 rows x 7 columns]

# %%
# USANDO O 'to_csv' PARA EXPORTAR O ARQUIVO
# O 'index=False' salva sem a coluna de indece e o 'header=False' salva sem o cabeçalho/titulo das colunas
mapadecaixa.to_csv('Filial_'+filial+' - MapaCaixa.csv', encoding='latin-1', header=False, index=False) 
# print('Existem Linhas em Branco na coluna:','\n',mapadecaixa[mapadecaixa['DEBITO'].isnull()])
# print("Existem:",mapadecaixa['DEBITO'].isnull().sum(),"Contas em branco na coluna DÉBITO")
# mapadecaixa.isnull().sum()

# %%
mapadecaixa

# %%
# LENDO O ARQUIVO csv
mapadecaixa = pd.read_csv(os.getcwd() + "\\MapaCaixa.csv", encoding='ANSI', sep=',', header=0)
mapadecaixa.head()
