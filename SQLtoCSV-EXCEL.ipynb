# %%
## https://www.codetd.com/pt/article/12083018
# https://www.youtube.com/watch?v=_phkptSCUNM
## pip install pandas psycopg2-binary SQLAlchemy
# from selenium import webdriver
# import lxml
import pandas as pd
import numpy as np
import os
from pathlib import Path
# import html5lib 
# from bs4 import BeautifulSoup
# import re
# import requests
## Postgress
import psycopg2 as pg
# from sqlalchemy import engine
from sqlalchemy import create_engine
## Mysql
import pymysql as mysql 
# import mysql.connector
# from mysql.connector import Error
## Oracle
import cx_Oracle as Oracle
## SQL Server
import pyodbc 
# from pyodbc import connect

# %%
#-CRIANDO CONEXÃO COM BD Oracler:
# engine = pg.connect('oracle: // nome de usuário: senha @ host: porta / sid')
engine = create_engine ('oracle://nome de usuário:senha@host:porta/sid')

# %%
#-CONSULTANDO TABELA NO BANCO DE DADOS Oracler
df = pd.read_sql('select * from produtos', engine)
df

# %%
#-CRIANDO CONEXÃO COM BD SQL Sever:
# engine = pg.connect("dbname='ecommerce' user='LASER\lmiguel' host='LE005TIC02\SQLEXPRESS' port='5432' password='root'")

# server = 'LE005TIC02\SQLEXPRESS' 
# database = 'ecommerce' 
# username = 'LASER\lmiguel' 
# password = 'Lmbs7811$' 
# cnxn = pyodbc.connect('DRIVER={SQL Server};SERVER='+server+';DATABASE='+database+';UID='+username+';PWD='+ password)
# cursor = cnxn.cursor()

cnxn = pyodbc.connect(Trusted_Connection='Yes',Driver= '{SQL Server}',Server='LE005TIC02\SQLEXPRESS',Database='ecommerce',UID ='LASER\lmiguel',PWD ='Lmbs7811$')
cursor = cnxn.cursor()

# %%
#-CONSULTANDO TABELA NO BANCO DE DADOS SQL Sever
df = pd.read_sql('select * from produtos', cnxn)
df

# %%
#--CRIANDO CONEXÃO COM BD Mysql:
# connect = create_engine ('mysql + pymysql: // nome de usuário: senha @ host: porta / dbname')
engine = create_engine('mysql+pymysql://root:root@127.0.0.1:3306/ecommerce')

# %%
#--CONSULTANDO TABELA NO BANCO DE DADOS Mysql
df = pd.read_sql('select * from produtos', engine)
df
# Armazene o DataFrame pandas no banco de dados MySQL:
# Insert python pandas dataframe to a SQL Server table
# df_clientes.to_sql('clientes', cnxn, if_exists='replace')
# df.to_sql('tablename', engine, index=False, if_exists='append')
# df.to_sql('pedidos', engine, index=False, if_exists='append') # if_exists='replace'
# Out:
#     id_produto                                         nome    preco  \
# 0            1                         Smart TV Samsung 18p  25111.0
# 1            2                                   Smartphone   2620.8
# 2            3                          Estabilizador 300va    150.0
# 3            4                                  Monitor 18P    350.9
# 4            8                                  Teclado usb     10.5
# 5            9                                  Teclado usb     10.5
# 6           10                                    Mouse usb      5.5
# 7           11                                   Mouse wifi     15.5
# 8           12                                   Mouse wifi     15.5
# 9           13                                   Mouse wifi     15.5
# 10          14                                     roteador     50.5
# 11          15                                  Roteador 5G     20.5
# 12          17                               Roteador Cisco     50.5
# 13          18                               Teclado Lenovo     15.0
# 14          19                                  Mouse Gamer     30.0
# 15          20                                Gabinte Gamer    250.1
# 16          21                                Fone Blutooth    180.6
# 17          22                              Placa Mae Gamer    780.5
# 18          23                         Placa de video GF500    500.1
# 19          24                               NVIDIA GeForce  10200.0
# 20          25  Placa de Vídeo Asus NVIDIA GeForce RTX 3070  10000.0
# 21          26  Placa de Vídeo Asus NVIDIA GeForce RTX 3070  10000.0
# 22          27  Placa de Vídeo Asus NVIDIA GeForce RTX 3070  10000.0
# 23          28       Placa de Vídeo NVIDIA GeForce RTX 3060  10500.0
# 24          30                       NVIDIA_GeForceRTX 3080   9400.5
# 25          31              Fone de ouvido Blutooth Edifier    250.1
# 4  2021-10-21 09:29:18
# 5  2021-10-21 09:29:18
# 6  2021-10-21 09:29:18
# 7  2021-10-21 09:29:18
# 8  2021-10-21 09:29:18
# 9  2021-10-21 09:29:18
# 10 2021-10-21 09:29:18
# 11 2021-10-21 09:29:18
# 12 2021-10-21 09:29:18
# 13 2021-10-21 09:29:18
# 14 2021-10-21 09:29:18
# 15 2021-10-21 09:29:18
# 16 2021-10-21 09:29:18
# 17 2021-10-21 09:29:18
# 18 2021-10-21 09:29:18
# 19 2021-10-21 09:29:18
# 20 2021-10-21 09:29:18
# 21 2021-10-21 09:29:18
# 22 2021-10-21 09:29:18
# 23 2021-10-21 09:29:18
# 24 2021-10-21 09:29:18
# 25 2021-10-21 09:29:18
# 26 2021-10-21 09:29:18
# 27 2021-10-21 09:29:18
# 28 2021-10-21 09:29:18
# 29 2021-10-21 09:29:18
# 30 2021-10-21 09:29:18
# 31 2021-10-21 09:29:18
# 32 2021-10-21 09:29:18
# 33 2021-10-21 09:29:18
# 34 2021-10-21 09:29:18
# 35 2021-10-21 09:29:18
# 36 2021-10-21 09:29:18

# %%
#---CRIANDO CONEXÃO COM BD Postgres:
engine = pg.connect("dbname='ecommerce' user='postgres' host='127.0.0.1' port='5432' password='root'")

# %%
#---CONSULTANDO TABELA NO BANCO DE DADOS Postgres
df = pd.read_sql('select * from products', engine)
df
# Out:
# C:\Users\lmiguel\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#      sku                    nome  quantidade    preco  \
# 0      8          Fonte ATX500va          10   800.19
# 1     79             Cabo usb 2m          30    10.50
# 2     10     Estabilizador 500va          42   750.50
# 3     11     Estabilizador 300va          63   300.50
# 4     13         SmartPhone Asus          60  3000.50
# ..   ...                     ...         ...      ...
# 112  120          PenDriver 64gb          15    50.00
# 113  133       HD Externo 2tb WD           5  1800.00
# 114  134  HD Externo 2tb Samsung           5  1700.00
# 115  135          PenDriver 64gb          15    50.00
# 116  136  HD Externo 8tb Samsung           2  5700.00
#
#                        created                   modified
# 0   2021-10-21 09:38:11.646840                        NaT
# 1   2021-10-21 09:38:11.646840                        NaT
# 2   2021-10-21 09:38:11.646840                        NaT
# 3   2021-10-21 09:38:11.646840                        NaT
# 4   2021-10-21 09:38:11.646840                        NaT
# ..                         ...                        ...
# 112 2021-10-21 09:38:11.646840 2021-10-21 13:23:39.194926
# 113 2021-10-21 13:27:57.463482 2021-10-21 13:27:57.463482
# 114 2021-10-21 13:28:57.052392 2021-10-21 13:28:57.052392
# 115 2021-10-21 13:45:57.809763 2021-10-21 13:48:52.185216
# 116 2021-11-10 13:09:16.700369 2021-11-10 13:09:16.700369
#
# [117 rows x 6 columns]

# %%
# CRIANDO CONEXÃO COM BD
# host='127.0.0.1'
# port='5432'
# dbname='ecommerce'
# user='postgres'
# password='root'
# # tbname = 'products'
# connection = pg.connect("host='{}' port='{}' dbname='{}' user='{}' password='{}'"
#                         .format(host, port, dbname, user, password))

# %%
# CONSULTANDO NO BANCO DE DADOS
# df = pd.read_sql_query("select * from {}".format(tbname), con=connection)
# df = pd.read_sql_query('select * from "products"', con=connection)
# # df.info()
# df

# %%
namefile = input("Digite o nome do arquivo: ")
# Lista['NOME'] = namefile

# %%
# SALVANDO O FILE EM CSV
df.to_csv(namefile+'.csv', index=False) # O Index false, remove a coluna de indice que o dataframe cria no inicio.

# %%
# SALVANDO O FILE EM EXCEL
df.to_excel(namefile+'.xlsx', index=False) # O Index false, remove a coluna de indice que o dataframe cria no inicio.
